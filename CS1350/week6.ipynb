# %%
#exercise 3
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

class Manager(Employee):
    def __init__(self, name, salary, department):
        # Call super().__init__() for name and salary
        super().__init__(name, salary)
        # Add department
        self.department = department

    def display(self):
        # Print name, salary, and department
        print(f"Name: {self.name}")
        print(f"Salary: {self.salary}")
        print(f"Department: {self.department}")
        pass
# Test:
# mgr = Manager("Sarah", 85000, "Engineering")
# mgr.display()
# Add department

def display(self):
# Print name, salary, and department
pass
# Test:
# mgr = Manager("Sarah", 85000, "Engineering")
# mgr.display()
# Out:
#   Cell In[1], line 10
#     OOP_3.md 2026-09-17
#                   ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
#exercise 4
class A:
    def greet(self):
        print("Hello from A")
class B(A):
    def greet(self):
        print("Hello from B")
class C(A):
    def greet(self):
        print("Hello from C")
class D(B, C):
    pass
# Step 1: Predict — what will D.mro() return?
# Step 2: Run it and check:
# print(D.mro())
# Step 3: What does this print?
# d = D()
# d.greet()

# %%
#OOP4
#exercise 1

class Circle:
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        #Return pi * radius^2 (use 3.14159)
        pass
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        #Return width * height
        pass
class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height
    def area(self):
        #Return 0.5 * base * height
        pass

#Test:
#shapes = [Circle(10), Rectangle(5, 3), Triangle(6, 4)]
#for shape in shapes:
#print(f"Area: {shape.area():.2f}")
