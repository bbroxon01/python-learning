# %%
#3.1
#beginner
inventory = {"apples": 50, "bananas": 30, "oranges": 25}

total_items = sum(inventory.values())
print(f"There are", total_items, "total items." )
for item, value in inventory.items():
    print(f"{item}: {value}")
# Out:
# keys type: <class 'dict_keys'>
# values type: <class 'dict_values'>
# items type: <class 'dict_items'>
# apples: 50
# bananas: 30
# oranges: 25
# 105
# There are 105 total items.

# %%
# View objects are dynamic
print("\n=== Dynamic Views ===")
keys_view = inventory.keys()
print(f"Before: {keys_view}")
inventory["grapes"] = 25
print(f"After adding grapes: {keys_view}")
# Out:
# === Dynamic Views ===
# Before: dict_keys(['apples', 'bananas', 'oranges'])
# After adding grapes: dict_keys(['apples', 'bananas', 'oranges', 'grapes'])
